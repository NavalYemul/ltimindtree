-- %%
select * from dev.silver.sales_cleaned;

select sum (total_amount) as total from dev.silver.sales_cleaned;

select sum (total_amount) as total from dev.silver.sales_cleaned;


-- Count the number of regions in the TPCH schema from the samples catalog
select count(*) as region_count from samples.tpch.region;

-- List all region names in the TPCH schema
select r_name from samples.tpch.region;

select * from samples.tpch.lineitem;


-- pull insights from samples.tpch scheama 

select l.*, o.*
from samples.tpch.lineitem l
join samples.tpch.orders o
  on l.l_orderkey = o.o_orderkey;

select * from samples.tpcds_sf1.web_site where web_name= :web_name --and web_rec_start_date>:start_date



-select * from read_files("",format=>"xls")

select * from top3.customer
